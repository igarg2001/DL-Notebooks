# %% [markdown]
# this is the 0th lab of the DL course.

# %%
print('hello world')
# Out:
# hello world

# %%
print('this is the DL Course')
# Out:
# this is the DL Course

# %%
my_variable = 'Ishan'
print(my_variable)
# Out:
# Ishan

# %%
my_age = 20
my_age
# Out:
# 20

# %%
My_age
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-bc025b998b9a> in <module>()
# ----> 1 My_age
#
# NameError: name 'My_age' is not defined

# %%
2nd_variable = 'Garg'
# Out:
#   File "<ipython-input-7-0fd0be98afd9>", line 1
#     2nd_variable = 'Garg'
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# List of syntax rules for python variable names: "insert from course colab"

# %%
my_boolean = True

# %% [markdown]
# mym

# %%
my_none = None

# %%
'ishan'  + 21 #TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-7007e23504ed> in <module>()
# ----> 1 'ishan'  + 21
#
# TypeError: can only concatenate str (not "int") to str

# %%
10/6 #returns float
# Out:
# 1.6666666666666667

# %%
10//6 #returns int
# Out:
# 1

# %%
10**2 #exponent
# Out:
# 100

# %%
True + False
# Out:
# 1

# %%
True*False
# Out:
# 0

# %%
True - False
# Out:
# 1

# %%
False - True
# Out:
# -1

# %%
None

# %%
None + 2 #TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-fdc93d486f4a> in <module>()
# ----> 1 None + 2
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'

# %% [markdown]
# # Lists

# %%
my_list = [10, 20, 30, 40, 50]
my_list
# Out:
# [10, 20, 30, 40, 50]

# %%
type(my_list)
# Out:
# list
